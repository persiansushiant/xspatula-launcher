# %% [markdown]
# ## Imports and setup
#
# Create a path to the notebook and import the required library (_Initiate_process_) for running xspatula. Leave it as it is and run it.

# %%
import sys
print(sys.executable)

# !{sys.executable} -m pip install python-dotenv
# Out:
# C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\.venv\Scripts\python.exe
# Requirement already satisfied: python-dotenv in C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\.venv\Lib\site-packages (1.2.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Standard library imports
from os import path, getcwd

import sys

# Get the working directory of the notebook
notebook_path = getcwd()

# Set the path to the root directory of this jupyter notebook (python) project
module_path = path.abspath(path.join('..'))

if module_path not in sys.path:
    
    sys.path.append(module_path)

# Package application imports
from xspatula.setup import Initiate_database

# %% [markdown]
# ## Scheme file
# To run this cell you need to set the [scheme_file](https://xspatula.github.io/setup_core_db_docs/framework/scheme_file/), that defines the location (path) to the project and associated process files, your user and the database to use. You can set the path to the scheme file with a relative path (relative to this notebook), in your home directory using tilde (~) or with an absolute path in the syntax of your operating system.

# %%
# Set the path to the scheme_file 
 
scheme_file = './zzz/scheme_ai4sh_local_setup.json'

# %% [markdown]
# ## Setup database
# Edit the [job_file](https://xspatula.github.io/setup_core_db_docs/framework/job_file/) and the [process_files](https://xspatula.github.io/setup_core_db_docs/framework/process_file/) that the job file points to and define the database, schemas and tables you want to setup. Then run the cell to setup the database and its content.
#
# **process**: setup_db
#
# **job_file**: job_setup_db.json

# %%
job_file = 'job_setup_db.json'

Initiate_database(notebook_path, scheme_file, job_file)
# Out:
# Scheme file: ./zzz/scheme_ai4sh_local_setup.json
#
# . Using project/process file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\job_setup_db.json
# .   Running <pilot_file>: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\db_xspatula_ai4sh_setup.txt
#
# .   ⚠️  Confirm that you want to set up the database.
#
#
# ⚠️    ✅  Set up database ai4sh??: y
#       ❌ To skip/quit: n
#
#
# . Setting up system production database: ai4sh
#
# . Database environment files created in: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\src\postgres\environment
# .   Current database: postgres
# .   User: postgres
# .   Databases: ['postgres', 'soil_health', 'template1', 'template0', 'soil_health_db', 'db_learning', 'sqlalchemy_shop', 'taskflow_db', 'questboard_db', 'minispatula_db', 'boothline', 'ai4soil']
# .   Databases to create: ai4sh
# .    Creating database: ai4sh
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\schema/schema_v10_sql.json
# .   Creating schema: utility
# .   Creating schema: community
# .   Creating schema: process
# .   Creating schema: landscape_utility
# .   Creating schema: landscape
# .   Creating schema: observation_utility
# .   Creating schema: observation
# .   Creating schema: edna_utility
# .   Creating schema: edna
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\utility/utility_v10_sql.json
# .   Creating schema.table: utility.foreign_key
# .   Inserting records to schema.table: utility.foreign_key
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\utility/territory_v10_sql.json
# .   Creating schema.table: utility.territory
# .   Inserting records to schema.table: utility.territory
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\community/user_categories_v10_sql.json
# .   Creating schema.table: community.user_categories
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\community/user_categories_records_v10_sql.json
# .   Inserting records to schema.table: community.user_categories
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\community/organisation_v10_sql.json
# .   Creating schema.table: community.organisation
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\community/organisation_records_v10_sql.json
# .   Inserting records to schema.table: community.organisation
# .   Inserting records to schema.table: community.organisation
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\community/user_v10_sql.json
# .   Creating schema.table: community.user
# .   Creating schema.table: community.user_media
# .   Creating schema.table: community.user_activity
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\community/user_records_v10_sql.json
# .   Inserting records to schema.table: community.user
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\process/processes_v10_sql.json
# .   Creating schema.table: process.root_process
# .   Creating schema.table: process.process
# .   Creating schema.table: process.process_parameter
# .   Creating schema.table: process.process_parameter_set_value
# .   Creating schema.table: process.process_parameter_minmax
# .   Creating schema.table: process.process_parameter_schema_table
# .   Creating schema.table: process.process_parameter_permission
# .   Creating schema.table: process.process_parameter_inherit
# .   Creating schema.table: process.process_parameter_auto_name
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\process/processes_records_v10_sql.json
# .   Inserting records to schema.table: process.root_process
# .   Inserting records to schema.table: process.root_process
# .   Inserting records to schema.table: process.process
# .   Inserting records to schema.table: process.process
# .   Inserting records to schema.table: process.process_parameter
# .   Inserting records to schema.table: process.process_parameter
# .   Inserting records to schema.table: process.process_parameter_set_value
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/analysis_method_v10_sql.json
# .   Creating schema.table: observation_utility.analysis_method
# .   Inserting records to schema.table: observation_utility.analysis_method
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/apparatus_v10_sql.json
# .   Creating schema.table: observation_utility.apparatus
# .   Inserting records to schema.table: observation_utility.apparatus
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/classification_v10_sql.json
# .   Creating schema.table: observation_utility.order
# .   Inserting records to schema.table: observation_utility.order
# .   Creating schema.table: observation_utility.family
# .   Inserting records to schema.table: observation_utility.family
# .   Creating schema.table: observation_utility.genus
# .   Inserting records to schema.table: observation_utility.genus
# .   Creating schema.table: observation_utility.species
# .   Inserting records to schema.table: observation_utility.species
# .   Creating schema.table: observation_utility.specimen
# .   Inserting records to schema.table: observation_utility.specimen
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/image_v10_sql.json
# .   Creating schema.table: observation_utility.image_approach
# .   Inserting records to schema.table: observation_utility.image_approach
# .   Creating schema.table: observation_utility.image_substrate
# .   Inserting records to schema.table: observation_utility.image_substrate
# .   Creating schema.table: observation_utility.image_camera
# .   Inserting records to schema.table: observation_utility.image_camera
# .   Creating schema.table: observation_utility.image_setup
# .   Inserting records to schema.table: observation_utility.image_setup
# .   Creating schema.table: observation_utility.image_lightsource
# .   Inserting records to schema.table: observation_utility.image_lightsource
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/license_v10_sql.json
# .   Creating schema.table: observation_utility.license
# .   Inserting records to schema.table: observation_utility.license
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/location_method_v10_sql.json
# .   Creating schema.table: observation_utility.location_method
# .   Inserting records to schema.table: observation_utility.location_method
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/macrofauna_v10_sql.json
# .   Creating schema.table: observation_utility.macrofauna_extraction_method
# .   Creating schema.table: observation_utility.life_cycle_stage
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/method_tier_v10_sql.json
# .   Creating schema.table: observation_utility.method_tier
# .   Inserting records to schema.table: observation_utility.method_tier
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/microbiometer_version_v10_sql.json
# .   Creating schema.table: observation_utility.microbiometer_version
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/monolith_extraction_v10_sql.json
# .   Creating schema.table: observation_utility.monolith_excavation_method
# .   Inserting records to schema.table: observation_utility.monolith_excavation_method
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/preparation_v10_sql.json
# .   Creating schema.table: observation_utility.preparation
# .   Inserting records to schema.table: observation_utility.preparation
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/preservation_v10_sql.json
# .   Creating schema.table: observation_utility.preservation
# .   Inserting records to schema.table: observation_utility.preservation
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/provider_v10_sql.json
# .   Creating schema.table: observation_utility.provider
# .   Inserting records to schema.table: observation_utility.provider
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/quantity_v10_sql.json
# .   Creating schema.table: observation_utility.quantity
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/reference_proprietor_v10_sql.json
# .   Creating schema.table: observation_utility.reference_proprietor
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/setting_system_v10_sql.json
# .   Creating schema.table: observation_utility.setting_system
# .   Inserting records to schema.table: observation_utility.setting_system
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/soil_horizon_v10_sql.json
# .   Creating schema.table: observation_utility.soil_horizon
# .   Inserting records to schema.table: observation_utility.soil_horizon
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/sound_v10_sql.json
# .   Creating schema.table: observation_utility.sound_mic
# .   Inserting records to schema.table: observation_utility.sound_mic
# .   Creating schema.table: observation_utility.sound_setup
# .   Inserting records to schema.table: observation_utility.sound_setup
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/spatial_reference_v10_sql.json
# .   Creating schema.table: observation_utility.spatial_reference
# .   Inserting records to schema.table: observation_utility.spatial_reference
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/spectroscopy_method_v10_sql.json
# .   Creating schema.table: observation_utility.spectroscopy_method
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/storage_v10_sql.json
# .   Creating schema.table: observation_utility.storage
# .   Inserting records to schema.table: observation_utility.storage
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/taxa_level_v10_sql.json
# .   Creating schema.table: observation_utility.taxa_level
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/taxa_status_v10_sql.json
# .   Creating schema.table: observation_utility.taxa_status
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/transportation_v10_sql.json
# .   Creating schema.table: observation_utility.transportation
# .   Inserting records to schema.table: observation_utility.transportation
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/unit_v10_sql.json
# .   Creating schema.table: observation_utility.unit
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/analysis_method_translate_v10_sql.json
# .   Creating schema.table: observation_utility.analysis_method_translate
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/indicator_v10_sql.json
# .   Creating schema.table: observation_utility.indicator
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/indicator_default_unit_v10_sql.json
# .   Creating schema.table: observation_utility.indicator_default_unit
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/juxtaposition_v10_sql.json
# .   Creating schema.table: observation_utility.juxtaposition
# .   Inserting records to schema.table: observation_utility.juxtaposition
# .   Creating schema.table: observation_utility.composition
# .   Inserting records to schema.table: observation_utility.composition
# .   Creating schema.table: observation_utility.proximity
# .   Inserting records to schema.table: observation_utility.proximity
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/profiling_v10_sql.json
# .   Creating schema.table: observation_utility.profiling
# .   Inserting records to schema.table: observation_utility.profiling
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/provision_v10_sql.json
# .   Creating schema.table: observation_utility.provision
# .   Inserting records to schema.table: observation_utility.provision
# .   Creating schema.table: observation_utility.provision_method_tier
# .   Creating schema.table: observation_utility.provision_serial_nr
# .   Inserting records to schema.table: observation_utility.provision_serial_nr
# .   Creating schema.table: observation_utility.provision_calibration
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/provision_indicator_v10_sql.json
# .   Creating schema.table: observation_utility.provision_indicator
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/spectrometer_v10_sql.json
# .   Creating schema.table: observation_utility.spectrometer
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/quantity_default_unit_v10_sql.json
# .   Creating schema.table: observation_utility.quantity_default_unit
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/taxa_v10_sql.json
# .   Creating schema.table: observation_utility.taxa
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/taxa_function_v10_sql.json
# .   Creating schema.table: observation_utility.taxa_function
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation_utility/unit_translate_v10_sql.json
# .   Creating schema.table: observation_utility.unit_translate
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/data_source_v10_sql.json
# .   Creating schema.table: observation.data_source
# .   Inserting records to schema.table: observation.data_source
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/person_v10_sql.json
# .   Creating schema.table: observation.person
# .   Inserting records to schema.table: observation.person
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/dataset_v10_sql.json
# .   Creating schema.table: observation.dataset
# .   Inserting records to schema.table: observation.dataset
# .   Creating schema.table: observation.dataset_meta
# .   Inserting records to schema.table: observation.dataset_meta
# ❌ ERROR - No unique columns found for table observation.dataset_meta
# .   Creating schema.table: observation.dataset_method_tier
# .   Creating schema.table: observation.dataset_location
# .   Creating schema.table: observation.dataset_setting_system
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/campaign_v10_sql.json
# .   Creating schema.table: observation.campaign
# .   Creating schema.table: observation.campaign_meta
# .   Creating schema.table: observation.campaign_method_tier
# .   Creating schema.table: observation.campaign_location
# .   Creating schema.table: observation.campaign_provision
# .   Creating schema.table: observation.campaign_setting_system
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/sampling_log_v10_sql.json
# .   Creating schema.table: observation.sampling_log
# .   Creating schema.table: observation.sampling_log_setting_system
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/sample_geolocation_v10_sql.json
# .   Creating schema.table: observation.geolocation
# .   Inserting records to schema.table: observation.geolocation
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/sample_v10_sql.json
# .   Creating schema.table: observation.sample
# .   Creating schema.table: observation.sample_juxtaposition
# .   Creating schema.table: observation.sample_profile
# .   Creating schema.table: observation.sample_geotag
# .   Creating schema.table: observation.sample_composition
# .   Creating schema.table: observation.sample_proximity
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/observation_log_v10_sql.json
# .   Creating schema.table: observation.observation_log
# .   Creating schema.table: observation.observation_log_meta
# .   Creating schema.table: observation.observation_log_method_tier
# .   Creating schema.table: observation.observation_log_provision
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/observation_v10_sql.json
# .   Creating schema.table: observation.observation
# .   Creating schema.table: observation.observation_temperature
# .   Creating schema.table: observation.observation_provision_serial_nr
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/infiltration_beerkan_v10_sql.json
# .   Creating schema.table: observation.infiltration_beerkan
# .   Creating schema.table: observation.infiltration_beerkan_time
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/macrofauna_v10_sql.json
# .   Creating schema.table: observation.monolith
# .   Creating schema.table: observation.macrofauna
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/macrofauna_image_v10_sql.json
# .   Creating schema.table: observation_utility.macrofauna_image_setting
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\observation/measurement_v10_sql.json
# .   Creating schema.table: observation.measurement
# .   Creating schema.table: observation.observation_measurement_array
# .   Creating schema.table: observation.observation_measurement
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\landscape/utility_v10_sql.json
# .   Creating schema.table: landscape_utility.major_landform
# .   Creating schema.table: landscape_utility.slope_position
# .   Creating schema.table: landscape_utility.sky_condition
# .   Creating schema.table: landscape_utility.ground_condition
# .   Creating schema.table: landscape_utility.cultivation_species
# .   Creating schema.table: landscape_utility.soil_preparation
# .   Creating schema.table: landscape_utility.crop_growth_stage
# .   Creating schema.table: landscape_utility.erosion_conservation_measure
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\landscape/observation_v10_sql.json
# .   Creating schema.table: landscape.sampling_weather
# .   Creating schema.table: landscape.cultivation
# .   Creating schema.table: landscape.landscape_state
# .   Creating schema.table: landscape.landscape_geomorphology
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\edna/utility_v10_sql.json
# .   Creating schema.table: edna_utility.sequence_library
# .   Creating schema.table: edna_utility.nucleotide_archive
# .   Creating schema.table: edna_utility.extraction
# .   Creating schema.table: edna_utility.amplification
# .   Creating schema.table: edna_utility.purification
# .   Creating schema.table: edna_utility.sequencing
# .   Creating schema.table: edna_utility.metabarcoding_pipeline
# .   Creating schema.table: edna_utility.bioinformatics
#
# . Reading json file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_db\json_ai4sh\edna/observation_v10_sql.json
# .   Creating schema.table: edna.edna_nucleotide
# .   Creating schema.table: edna.taxa_bioinformatics
# .   Creating schema.table: edna.edna_measurement
# .   Creating schema.table: edna.taxa_biodiversity_measurement
# {'process': [{'process_id': 'create_table', 'overwrite': False, 'delete': False, 'parameters': {'schema': 'edna', 'table': 'edna_nucleotide', 'command': ['id SERIAL', 'sample_id INTEGER', 'nucleotide_archive_id INTEGER', 'accession_code TEXT', 'accession_url TEXT', 'PRIMARY KEY (id)']}, 'execute': True, 'verbose': 1, 'src_path': {'volume': '.', 'ext': 'json'}}, {'process_id': 'create_table', 'overwrite': False, 'delete': False, 'parameters': {'schema': 'edna', 'table': 'taxa_bioinformatics', 'command': ['id SERIAL', 'edna_id INTEGER', 'barcoding_pipeline_id INTEGER', 'bioninformatics_treatment_date DATE', 'taxa_id INTEGER', 'biodiverity_id INTEGER', 'PRIMARY KEY (id)']}, 'execute': True, 'verbose': 1, 'src_path': {'volume': '.', 'ext': 'json'}}, {'process_id': 'create_table', 'overwrite': False, 'delete': False, 'parameters': {'schema': 'edna', 'table': 'edna_measurement', 'command': ['id BIGSERIAL', 'observation_id INTEGER', 'indicator_id INTEGER', 'value REAL', 'standard_deviation REAL', 'n_repeat SMALLINT', 'PRIMARY KEY (observation_id,indicator_id)']}, 'execute': True, 'verbose': 1, 'src_path': {'volume': '.', 'ext': 'json'}}, {'process_id': 'create_table', 'overwrite': False, 'delete': False, 'parameters': {'schema': 'edna', 'table': 'taxa_biodiversity_measurement', 'command': ['id SERIAL', 'bioinformatics_id INTEGER', 'value REAL', 'PRIMARY KEY (id)']}, 'execute': True, 'verbose': 1, 'src_path': {'volume': '.', 'ext': 'json'}}], 'project_path': './ai4sh', 'postgresdb': {'host': 'localhost', 'port': 5432, 'db': 'ai4sh', 'user_name': 'postgres', 'password': '!aA1!aA1', 'db_users': [{'user_id': 'community_admin', 'password': 'guessing-rubble-garden-opera', 'role': 'community_admin'}, {'user_id': 'login_evaluation', 'password': 'hippodrome-bicycle-concert-shuttle', 'role': 'login_evaluation'}, {'user_id': 'user_cat_0', 'password': 'tablecloth-summerleaf-riverbasin-vacuumcleaner', 'role': 'user_cat_1'}, {'user_id': 'user_cat_1', 'password': 'secret-parsimony-archipelago-hedgehog', 'role': 'user_cat_1'}, {'user_id': 'user_cat_2', 'password': 'sailing-courageous-upsidedown-castle', 'role': 'user_cat_2'}, {'user_id': 'user_cat_3', 'password': 'rollerscates-forever-skyline-coconut', 'role': 'user_cat_3'}, {'user_id': 'user_cat_4', 'password': 'superfluid-altruistic-guitarplayer-climatechange', 'role': 'user_cat_4'}, {'user_id': 'user_cat_5', 'password': 'fireplace-olympicgames-grassroot-luminescence', 'role': 'user_cat_5'}]}}
#
# . Database roles defined: ['community_admin', 'login_evaluation', 'user_cat_0', 'user_cat_1', 'user_cat_2', 'user_cat_3', 'user_cat_4', 'user_cat_5']
