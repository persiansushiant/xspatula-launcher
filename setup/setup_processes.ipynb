# %% [markdown]
# ## Imports and setup
#
# The first cell creates a path to the notebook and imports the required library (_Initiate_process_) for running Xspatula. Leave it as it is and run it.

# %%
# Standard library imports
from os import path, getcwd

import sys 

# Get the working directory of the notebook
notebook_path = getcwd()

# Set the path to the root directory of this jupyter notebook (python) project
module_path = path.abspath(path.join('..'))

if module_path not in sys.path:
    
    sys.path.append(module_path)

# Package application imports
from xspatula import Initiate_process 

from xspatula.setup import Run_process

# %% [markdown]
# ## Scheme file
# To run this cell you need to set the [scheme_file](https://xspatula.github.io/setup_core_db_docs/framework/scheme_file/), that defines the location (path) to the project and associated process files and your user. You can set the path to the scheme file with a relative path (relative to this notebook), in your home directory using tilde (~) or with an absolute path in the syntax of your operating system.

# %%
# Set the path to the scheme_file  

scheme_file = './zzz/scheme_ai4sh_local_use_pswd.json'

# %% [markdown]
# ## Setup processes
# If you are defining an Xspatula database-integrated python modelling framework from scratch you need to write the python code yourself. Use the predefined framework as a template for writing. There are several [projects] in the pipeline, but none is yet available online.
#
# Edit the [job_file](https://xspatula.github.io/setup_core_db_docs/framework/job_file/) and the [process_files](https://xspatula.github.io/setup_core_db_docs/framework/process_file/) that the job file points to and define processes arguments for any process you want to add to the database. Then run the cell to insert the process parameters in the database.
#
# **process**: add_process
#
# **job_file**: job_setup_processes.json

# %%
job_file = 'job_setup_processes.json'

structured_process_D, scheme_params_D = Initiate_process(notebook_path, scheme_file, job_file)

if structured_process_D is not None:
    
    Run_process(structured_process_D, scheme_params_D)
# Out:
# Scheme file: ./zzz/scheme_ai4sh_local_use_pswd.json
#
# . Using project/process file: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\job_setup_processes.json
# .   Running <pilot_file>: C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_processes\ai4sh_setup_processes.txt
#
#     reading JSON:
#     C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_processes\json_ai4sh\root_process/root_processes_v10_sql.json
#
#     reading JSON:
#     C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_processes\json_ai4sh\translate/translate_tabular_data_v10_sql.json
#
#     reading JSON:
#     C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_processes\json_ai4sh\utility/foreign_key_v10_sql.json
#
#     reading JSON:
#     C:\Users\faha6654\PycharmProjects\xspatula_ai4sh\setup\zzz\ai4sh\setup_processes\json_ai4sh\utility/territory_v10_sql.json
#
#     reading JSON:
# ...
